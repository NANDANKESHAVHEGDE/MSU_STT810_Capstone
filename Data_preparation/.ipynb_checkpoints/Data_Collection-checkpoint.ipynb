# %%
# !pip install kagglehub
# Out:
# Collecting kagglehub
#   Downloading kagglehub-0.3.3-py3-none-any.whl (42 kB)
#                                               0.0/42.9 kB ? eta -:--:--
#      ---------------------------------------- 42.9/42.9 kB 2.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging in c:\users\nandan hegde\anaconda3\lib\site-packages (from kagglehub) (23.0)
# Requirement already satisfied: requests in c:\users\nandan hegde\anaconda3\lib\site-packages (from kagglehub) (2.32.3)
# Requirement already satisfied: tqdm in c:\users\nandan hegde\anaconda3\lib\site-packages (from kagglehub) (4.65.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\nandan hegde\anaconda3\lib\site-packages (from requests->kagglehub) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\nandan hegde\anaconda3\lib\site-packages (from requests->kagglehub) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\nandan hegde\anaconda3\lib\site-packages (from requests->kagglehub) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\nandan hegde\anaconda3\lib\site-packages (from requests->kagglehub) (2024.8.30)
# Requirement already satisfied: colorama in c:\users\nandan hegde\anaconda3\lib\site-packages (from tqdm->kagglehub) (0.4.6)
# Installing collected packages: kagglehub
# Successfully installed kagglehub-0.3.3

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("mkechinov/ecommerce-events-history-in-electronics-store")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/mkechinov/ecommerce-events-history-in-electronics-store?dataset_version_number=1...
# 100%|█████████████████████████████████████████████████████████████████████████████| 20.3M/20.3M [00:01<00:00, 14.9MB/s]
# Extracting files...
# Path to dataset files: C:\Users\Nandan Hegde\.cache\kagglehub\datasets\mkechinov\ecommerce-events-history-in-electronics-store\versions\1

# %%
import pandas as pd

# Specify the full path to the CSV file
file_path = r"C:\Users\Nandan Hegde\.cache\kagglehub\datasets\mkechinov\ecommerce-events-history-in-electronics-store\versions\1\events.csv"

# Read the CSV file
df = pd.read_csv(file_path)

# Check the first few rows to ensure the data was read correctly
print(df.head())
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2020-09-24 11:57:06 UTC       view     1996170  2144415922528452715
# 1  2020-09-24 11:57:26 UTC       view      139905  2144415926932472027
# 2  2020-09-24 11:57:27 UTC       view      215454  2144415927158964449
# 3  2020-09-24 11:57:33 UTC       view      635807  2144415923107266682
# 4  2020-09-24 11:57:36 UTC       view     3658723  2144415921169498184
#
#                    category_code        brand   price              user_id  \
# 0          electronics.telephone          NaN   31.90  1515915625519388267
# 1    computers.components.cooler       zalman   17.16  1515915625519380411
# 2                            NaN          NaN    9.81  1515915625513238515
# 3  computers.peripherals.printer       pantum  113.81  1515915625519014356
# 4                            NaN  cameronsino   15.87  1515915625510743344
#
#   user_session
# 0   LJuJVLEjPT
# 1   tdicluNnRY
# 2   4TMArHtXQy
# 3   aGFYrNgC08
# 4   aa4mmk0kwQ

# %%
df.describe()
# Out:
#          product_id   category_id          price       user_id
# count  8.851290e+05  8.851290e+05  885129.000000  8.851290e+05
# mean   1.906621e+06  2.144423e+18     146.328713  1.515916e+18
# std    1.458708e+06  6.165105e+14     296.807683  3.554165e+07
# min    1.020000e+02  2.144416e+18       0.220000  1.515916e+18
# 25%    6.988030e+05  2.144416e+18      26.460000  1.515916e+18
# 50%    1.452883e+06  2.144416e+18      65.710000  1.515916e+18
# 75%    3.721194e+06  2.144416e+18     190.490000  1.515916e+18
# max    4.183880e+06  2.227847e+18   64771.060000  1.515916e+18

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("mkechinov/ecommerce-behavior-data-from-multi-category-store")

print("Path to dataset files:", path)
# Out:
# Downloading from https://www.kaggle.com/api/v1/datasets/download/mkechinov/ecommerce-behavior-data-from-multi-category-store?dataset_version_number=8...
# 100%|█████████████████████████████████████████████████████████████████████████████| 4.29G/4.29G [07:47<00:00, 9.86MB/s]
# Extracting files...
# Path to dataset files: C:\Users\Nandan Hegde\.cache\kagglehub\datasets\mkechinov\ecommerce-behavior-data-from-multi-category-store\versions\8

# %%
import pandas as pd

# Specify the full path to the CSV file
file_path = r"C:\Users\Nandan Hegde\.cache\kagglehub\datasets\mkechinov\ecommerce-behavior-data-from-multi-category-store\versions\8\2019-Nov.csv"

# Read the CSV file
df = pd.read_csv(file_path,nrows=100)

# Check the first few rows to ensure the data was read correctly
print(df.head())
# Out:
#                 event_time event_type  product_id          category_id  \
# 0  2019-11-01 00:00:00 UTC       view     1003461  2053013555631882655
# 1  2019-11-01 00:00:00 UTC       view     5000088  2053013566100866035
# 2  2019-11-01 00:00:01 UTC       view    17302664  2053013553853497655
# 3  2019-11-01 00:00:01 UTC       view     3601530  2053013563810775923
# 4  2019-11-01 00:00:01 UTC       view     1004775  2053013555631882655
#
#                category_code   brand   price    user_id  \
# 0     electronics.smartphone  xiaomi  489.07  520088904
# 1  appliances.sewing_machine  janome  293.65  530496790
# 2                        NaN   creed   28.31  561587266
# 3  appliances.kitchen.washer      lg  712.87  518085591
# 4     electronics.smartphone  xiaomi  183.27  558856683
#
#                            user_session
# 0  4d3b30da-a5e4-49df-b1a8-ba5943f1dd33
# 1  8e5f4f83-366c-4f70-860e-ca7417414283
# 2  755422e7-9040-477b-9bd2-6a6e8fd97387
# 3  3bfb58cd-7892-48cc-8020-2f17e6de6e7f
# 4  313628f1-68b8-460d-84f6-cec7a8796ef2
